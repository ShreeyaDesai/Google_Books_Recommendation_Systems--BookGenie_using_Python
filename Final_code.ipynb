# %%
# !pip install clean-text
# Out:
# Collecting clean-text
#   Downloading clean_text-0.6.0-py3-none-any.whl (11 kB)
# Collecting emoji<2.0.0,>=1.0.0 (from clean-text)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ---------------------------------------- 0.0/175.4 kB ? eta -:--:--
#      -------------------------- ----------- 122.9/175.4 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 175.4/175.4 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ftfy<7.0,>=6.0 (from clean-text)
#   Obtaining dependency information for ftfy<7.0,>=6.0 from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy<7.0,>=6.0->clean-text)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.4 kB ? eta -:--:--
#    ---------------------------------------- 53.4/53.4 kB ? eta 0:00:00
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171059 sha256=7502071163450d95e521001ef509d97aebe940e1e20cddec982236fa6e7eb998
#   Stored in directory: c:\users\msi_pc\appdata\local\pip\cache\wheels\bd\22\e5\b69726d5e1a19795ecd3b3e7464b16c0f1d019aa94ff1c8578
# Successfully built emoji
# Installing collected packages: wcwidth, emoji, ftfy, clean-text
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
# Successfully installed clean-text-0.6.0 emoji-1.7.0 ftfy-6.1.3 wcwidth-0.2.12

# %%
import requests
import csv

def fetch_books(query, api_key, total_results=10000):
    base_url = "https://www.googleapis.com/books/v1/volumes"
    max_results_per_request = 40  # Google Books API allows a maximum of 40 results per request
    num_requests = total_results // max_results_per_request

    with open('008106.csv', 'w', newline='', encoding='utf-8') as csv_file:
        fieldnames = ['BookID', 'Title', 'Authors', 'Description', 'AverageRating', 'Price', 'PublishedDate', 'Categories', 'Language']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()

        processed_book_ids = set()  # Set to store processed book IDs

        for i in range(num_requests):
            start_index = i * max_results_per_request
            params = {
                'q': query,
                'key': api_key,
                'maxResults': min(max_results_per_request, total_results - start_index),
                'startIndex': start_index
            }

            try:
                response = requests.get(base_url, params=params)
                response.raise_for_status()  # Check if the request was successful
                data = response.json()

                if 'items' in data:
                    for book in data['items']:
                        book_id = book['id']

                        # Check if the book has already been processed
                        if book_id in processed_book_ids:
                            continue

                        title = book['volumeInfo']['title']
                        authors = ', '.join(book['volumeInfo'].get('authors', ['Unknown Author']))
                        description = book['volumeInfo'].get('description', 'No description available')
                        average_rating = book['volumeInfo'].get('averageRating', 'Not rated')
                        price = book['saleInfo']['retailPrice']['amount'] if 'retailPrice' in book['saleInfo'] else 'Not available'
                        published_date = book['volumeInfo'].get('publishedDate', 'Not available')
                        categories = ', '.join(book['volumeInfo'].get('categories', []))
                        language = book['volumeInfo'].get('language', 'Unknown')

                        # Write book data to CSV
                        writer.writerow({
                            'BookID': book_id,
                            'Title': title,
                            'Authors': authors,
                            'Description': description,
                            'AverageRating': average_rating,
                            'Price': price,
                            'PublishedDate': published_date,
                            'Categories': categories,
                            'Language': language
                        })

                        # Add book ID to the set of processed book IDs
                        processed_book_ids.add(book_id)

            except requests.exceptions.HTTPError as err:
                print(f"Error: {err}")

if __name__ == "__main__":
    # Replace 'YOUR_API_KEY' with your actual Google Books API key
    api_key = 'AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk'
    search_query = input("Enter the book title or author: ")
    fetch_books(search_query, api_key, total_results=10000)
# Out:
# Enter the book title or author: Young Adult Fiction
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=40
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=80
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=360
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=440
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=560
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1000
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=1960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2000
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2280
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2360
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2440
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2480
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2520
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2560
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2640
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=2960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3000
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3040
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3360
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3440
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3480
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3560
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3920
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=3960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4000
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4200
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4320
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4360
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4440
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4480
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4560
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4720
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=4960
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5000
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5360
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5440
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5560
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5880
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=5960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6000
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6360
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6400
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6440
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6560
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=6960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7000
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7240
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7360
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7440
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7560
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=7960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8000
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8080
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8360
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8440
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8560
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8600
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8760
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8880
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=8960
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9000
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9040
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9080
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9120
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9160
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9200
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9240
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9280
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9320
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9360
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9400
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9440
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9480
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9520
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9560
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9600
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9640
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9680
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9720
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9760
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9800
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9840
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9880
# Error: 400 Client Error: Bad Request for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9920
# Error: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/books/v1/volumes?q=Young+Adult+Fiction&key=AIzaSyBjNhuKCXrtS8ouxWERJqHhqY2tMUWi8lk&maxResults=40&startIndex=9960

# %%
import pandas as pd

# List of CSV files to combine
csv_files = [
    '008001.csv',
    '008002.csv',
    '008010.csv',
    '008026.csv',
    '008031.csv',
    '008037.csv',
    '008043.csv',
    '008051.csv',
    '008055.csv',
    '008061.csv',
    '008067.csv',
    '008085.csv',
    '008106.csv'
]

# Initialize an empty list to store DataFrames
dfs = []

# Read each CSV file into a DataFrame and append to the list
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_books.csv', index=False)

print('Combined DataFrame saved to combined_books.csv')
# Out:
# Combined DataFrame saved to combined_books.csv

# %% [markdown]
# ## So far we have extracted the data here now we have to

# %%
import pandas as pd

# %%
combined_df = pd.read_csv('Final.csv')

# %%
df=combined_df

# %%
df
# Out:
#            BookID             Title            Authors  \
# 0      006054094X              1421      Gavin Menzies
# 1      1400032059              1491    Charles C. Mann
# 2       345455827              1968     Mark Kurlansky
# 3       452284236              1984      George Orwell
# 4       586203192              2061   Arthur C. Clarke
# ...           ...               ...                ...
# 24958   943015537  __ _______ _____     Chris Prentiss
# 24959  4770027729          ________                ___
# 24960  4770028016         ___ : ___              __á__
# 24961  4770028032         _________              _____
# 24962   520241827              ____  Yasunari Kawabata
#
#                                              Description  AverageRating  \
# 0      Based on 15 years of in-depth research, "1421"...           3.59
# 1      Describes how recent archaeological research h...           4.02
# 2      Provides a detailed look at 1968, a pivotal ye...           3.78
# 3      Portrays a terrifying vision of life in the fu...           4.17
# 4                                 Science fiction-roman.           3.55
# ...                                                  ...            ...
# 24958  The gentle wisdom of this resource explains ho...           4.04
# 24959                               ____54______________           3.76
# 24960  Book Of Five Rings is a Kodansha International...           4.08
# 24961  This is a student's guide to the expression of...           3.54
# 24962  A new translation of the only work not current...           3.35
#
#        Price PublishedDate              Categories Language
# 0        NaN          2004                 History      NaN
# 1        NaN          2006                 History      NaN
# 2        NaN          2005                 History      NaN
# 3        NaN          2003        London (England)      NaN
# 4        NaN          1997               Computers      NaN
# ...      ...           ...                     ...      ...
# 24958    NaN          2006              Philosophy      NaN
# 24959    NaN          2001                   Japan      NaN
# 24960    NaN          2002              Philosophy      NaN
# 24961    NaN          2002  Foreign Language Study      NaN
# 24962    NaN          2005                 Fiction      NaN
#
# [24963 rows x 9 columns]

# %%
from cleantext import clean


def clean_text(text):
    return clean(str(text), fix_unicode=True, to_ascii=True, lower=True, no_punct=False)

# Apply the clean_text function to each element in the DataFrame
df_cleaned = df.applymap(clean_text)

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
#            BookID             Title            Authors  \
# 0      006054094x              1421      gavin menzies
# 1      1400032059              1491    charles c. mann
# 2       345455827              1968     mark kurlansky
# 3       452284236              1984      george orwell
# 4       586203192              2061   arthur c. clarke
# ...           ...               ...                ...
# 24958   943015537  __ _______ _____     chris prentiss
# 24959  4770027729          ________                ___
# 24960  4770028016         ___ : ___              __a__
# 24961  4770028032         _________              _____
# 24962   520241827              ____  yasunari kawabata
#
#                                              Description AverageRating Price  \
# 0      based on 15 years of in-depth research, "1421"...          3.59   nan
# 1      describes how recent archaeological research h...          4.02   nan
# 2      provides a detailed look at 1968, a pivotal ye...          3.78   nan
# 3      portrays a terrifying vision of life in the fu...          4.17   nan
# 4                                 science fiction-roman.          3.55   nan
# ...                                                  ...           ...   ...
# 24958  the gentle wisdom of this resource explains ho...          4.04   nan
# 24959                               ____54______________          3.76   nan
# 24960  book of five rings is a kodansha international...          4.08   nan
# 24961  this is a student's guide to the expression of...          3.54   nan
# 24962  a new translation of the only work not current...          3.35   nan
#
#       PublishedDate              Categories Language
# 0              2004                 history      nan
# 1              2006                 history      nan
# 2              2005                 history      nan
# 3              2003        london (england)      nan
# 4              1997               computers      nan
# ...             ...                     ...      ...
# 24958          2006              philosophy      nan
# 24959          2001                   japan      nan
# 24960          2002              philosophy      nan
# 24961          2002  foreign language study      nan
# 24962          2005                 fiction      nan
#
# [24963 rows x 9 columns]

# %%
#df_cleaned.to_csv('cleaned_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_cleaned.to_csv('cleaned_data.csv', index=False)
#
# NameError: name 'df_cleaned' is not defined

# %%
df=pd.read_csv('cleaned_data.csv')

# %%
df
# Out:
#              BookID                                              Title  \
# 0        006054094x                                               1421
# 1        1400032059                                               1491
# 2         345455827                                               1968
# 3         452284236                                               1984
# 4         586203192                                               2061
# ...             ...                                                ...
# 24951  4azfcgaaqbaj                                     zuleika dobson
# 24952  zx9_aqaacaaj                                              zumba
# 24953  zguux-s69uoc        zurich international chess tournament, 1953
# 24954  b4t7rqaacaaj  zwilling j.a. henckels complete book of knife ...
# 24955  n4ceaaaaqaaj                                              zzyzx
#
#                                                  Authors  \
# 0                                          gavin menzies
# 1                                        charles c. mann
# 2                                         mark kurlansky
# 3                                          george orwell
# 4                                       arthur c. clarke
# ...                                                  ...
# 24951                                       max beerbohm
# 24952                                         beto perez
# 24953                                    david bronstein
# 24954  jeffrey elliot, james p. dewan, zwilling j.a. ...
# 24955                                     unknown author
#
#                                              Description  AverageRating  \
# 0      based on 15 years of in-depth research, "1421"...           3.59
# 1      describes how recent archaeological research h...           4.02
# 2      provides a detailed look at 1968, a pivotal ye...           3.78
# 3      portrays a terrifying vision of life in the fu...           4.17
# 4                                 science fiction-roman.           3.55
# ...                                                  ...            ...
# 24951  this satirical novel of life and love at oxfor...            NaN
# 24952  tired of logging hours at the gym and not gett...            NaN
# 24953  perceptive coverage of all 210 games from the ...            NaN
# 24954  anyone who wants to cook-- either professional...            NaN
# 24955  "the early settlers dubbed california the gold...            NaN
#
#        Price PublishedDate            Categories Language
# 0        NaN          2004               history      NaN
# 1        NaN          2006               history      NaN
# 2        NaN          2005               history      NaN
# 3        NaN          2003      london (england)      NaN
# 4        NaN          1997             computers      NaN
# ...      ...           ...                   ...      ...
# 24951   6.99    11/24/2015               fiction       en
# 24952    NaN          2014      physical fitness       en
# 24953   9.99    15-04-2013    games & activities       en
# 24954    NaN          2010               cooking       en
# 24955    NaN          2016  los angeles (calif.)       en
#
# [24956 rows x 9 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import warnings

warnings.filterwarnings("ignore")

import nltk
#nltk.download('stopwords')
#nltk.download('punkt')

# Text preprocessing function
def preprocess_text(text):
    if pd.isnull(text):
        return ''  # Return empty string for NaN values
    # Tokenization
    tokens = word_tokenize(text)

    # Lowercasing
    tokens = [token.lower() for token in tokens]

    # Removing Stop Words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    # Stemming
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Combine tokens back to text
    processed_text = ' '.join(tokens)

    return processed_text

# Apply text preprocessing to relevant columns
df['Processed_Authors'] = df['Authors'].apply(preprocess_text)

# Fill NaN values in 'Categories' column with an empty string
df['Categories'] = df['Categories'].fillna('')

# Apply text preprocessing to 'Categories' column
df['Processed_Categories'] = df['Categories'].apply(preprocess_text)

# Combine features into a single column
df['Combined_Features'] = (
    df['Description'] +
    ' ' +
    df['Processed_Authors'] +
    ' ' +
    df['Processed_Categories']
)

# Fill NaN values in 'Combined_Features' column with an empty string
df['Combined_Features'] = df['Combined_Features'].fillna('')

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Combined_Features'])

# Calculate cosine similarity
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Book recommendation function
def recommend_books(search_query, cosine_sim=cosine_sim):
    # Process the search query
    processed_query = preprocess_text(search_query)

    # Create a temporary DataFrame with the search query
    query_df = pd.DataFrame({'Combined_Features': [processed_query]})

    # TF-IDF Vectorization for the query
    query_vector = tfidf_vectorizer.transform(query_df['Combined_Features'])

    # Calculate cosine similarity between the query and all books
    sim_scores = linear_kernel(query_vector, tfidf_matrix).flatten()

    # Get indices of the most similar books
    book_indices = sim_scores.argsort()[::-1][:10]

    return df['Title'].iloc[book_indices]

# %%
# Example usage:
search_query = "Data Science"
recommended_books = recommend_books(search_query)
print(recommended_books)
# Out:
# 4596          mining new gold--managing your business data
# 8011                   practical synthetic data generation
# 3493                                    making data visual
# 8637                        r programming for data science
# 10315                           semantic modeling for data
# 21592                       thinking big data in geography
# 8636                                    r for data science
# 8556     quantitative analysis and modeling of earth an...
# 14966                               the data driven leader
# 3358     machine learning and big data analytics paradi...
# Name: Title, dtype: object

# %%
import pickle

# Save the model
model_data = {
    'df': df,
    'tfidf_vectorizer': tfidf_vectorizer,
    'tfidf_matrix': tfidf_matrix,
    'cosine_sim': cosine_sim
}

with open('book_recommendation_model.pkl', 'wb') as model_file:
    pickle.dump(model_data, model_file)

# Load the model
with open('book_recommendation_model.pkl', 'rb') as model_file:
    loaded_model_data = pickle.load(model_file)

# %%
# Extract necessary components from the loaded model data
loaded_df = loaded_model_data['df']
loaded_tfidf_vectorizer = loaded_model_data['tfidf_vectorizer']
loaded_tfidf_matrix = loaded_model_data['tfidf_matrix']
loaded_cosine_sim = loaded_model_data['cosine_sim']

# Example query after loading the model
search_query = "Machine Learning"
recommended_books = recommend_books(search_query, cosine_sim=loaded_cosine_sim)
print(recommended_books)
# Out:
# 16729    the hundred-page machine learning book
# 12463    symbolic knowledge and neural networks
# 23564        weird fiction in britain 1880-1939
# 13368             the art of the business lunch
# 22735                     understanding chakras
# 12230              summit math algebra 1 book 1
# 6703          opportunities in culinary careers
# 20810       the ultimate toddler activity guide
# 2791              listening with brain and body
# 13844                             the body book
# Name: Title, dtype: object

# %% [markdown]
# ### Text Preprocessing:
# 1. Tokenization: Split the text into individual words or phrases (tokens).
# 2. Lowercasing: Convert all text to lowercase to ensure consistency.
# 3. Removing Stop Words: Eliminate common words that don't contribute much to the meaning.
# 4. Removing Punctuation and Special Characters: Clean the text from non-alphabetic characters.
# 5. Lemmatization or Stemming: Reduce words to their base or root form.
#
# ### TF-IDF Vectorization:
# 6. Use TF-IDF Vectorization to convert the preprocessed text into numerical vectors.
#
# ### Handling NaN Values:
# 7. Replace any NaN values in the 'combined_features' column with an empty string.
#
# ### Cosine Similarity Calculation:
# 8. Calculate cosine similarity between each pair of books based on their TF-IDF vectors using the linear kernel.
#
# ### Building the Recommendation System:
# 9. Create a function, `get_recommendations`, to recommend books based on cosine similarity.
# 10. Retrieve the index of the input book title and calculate similarity scores with all other books.
# 11. Sort the scores in descending order to identify the most similar books.
# 12. Return the top 10 recommended book titles (excluding the input book) based on their similarity scores.
#
# ### Example Usage:
# 13. Demonstrate how to use the recommendation function for a specific book title.
